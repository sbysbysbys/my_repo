# %%
# 读取文件
from bs4 import BeautifulSoup
import math

def read_sgm_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    return content

def parse_sgm_content(content):
    soup = BeautifulSoup(content, 'html.parser')
    english_text = [text.text for text in soup.find_all('seg', id=lambda x: x != '0')]
    return english_text

file_path_en = 'WMT-18\\newstest2018-zhen-ref-ts.en.sgm'
file_path_zh = 'WMT-18\\newstest2018-zhen-src-ts.zh.sgm'
en_content = read_sgm_file(file_path_en)
zh_content = read_sgm_file(file_path_zh)
en_text = parse_sgm_content(en_content)
zh_text = parse_sgm_content(zh_content)
print(en_text[0])
print(zh_text[0])
#保存在本地
with open('WMT-18\\newstest2018-zhen-ref-ts.en.txt', 'w', encoding='utf-8') as file:
    file.write('\n'.join(en_text))
with open('WMT-18\\newstest2018-zhen-src-ts.zh.txt', 'w', encoding='utf-8') as file:
    file.write('\n'.join(zh_text))
# Out:
# Last week, the broadcast of period drama “Beauty Private Kitchen” was temporarily halted, and accidentally triggered heated debate about faked ratings of locally produced dramas.
# 上周，古装剧《美人私房菜》临时停播，意外引发了关于国产剧收视率造假的热烈讨论。

# %%
#放进翻译软件里面翻译
#读取翻译后的文件
import math
with open('WMT-18\\trans_result\\google.txt', 'r', encoding='utf-8') as file:
    google_text = file.read().split('\n')
    file.close()
with open('WMT-18\\trans_result\\sg.txt', 'r', encoding='utf-8') as file:
    sg_text = file.read().split('\n')
    file.close()
with open('WMT-18\\trans_result\\jscb.txt', 'r', encoding='utf-8') as file:
    jscb_text = file.read().split('\n')
    file.close()


with open('WMT-18\\newstest2018-zhen-ref-ts.en.txt', 'r', encoding='utf-8') as file:
    ref_text = file.read().split('\n')
    file.close()

# print(ref_text[412])
print(len(jscb_text))
print(len(google_text))
print(len(sg_text))

google_score = []
sg_score = []
jscb_score = []
for i in range(1,400): #(len(google_text)-1):
    google_p1 = []
    sg_p1 = []
    jscb_p1 = []
    ref_p1 = []
    

    # google
    word = ''
    for j in range(len(google_text[i])):
        char = google_text[i][j]
        if 'A' <= char <= 'Z' or 'a' <= char <= 'z' or '0' <= char <= '9':
            word = word + char
            continue
        else:
            if word != '':
                # print(word)
                google_p1.append(word)
                if char != ' ' and char != '\n':
                    google_p1.append(char)
                    # print(char)
                word = ''
    print(google_p1)
    google_p2 = []
    google_p3 = []
    google_p4 = []
    for j in range(len(google_p1)):
        if j< len(google_p1)-1:
            google_p2.append(google_p1[j]+google_p1[j+1])
        if j< len(google_p1)-2:
            google_p3.append(google_p1[j]+google_p1[j+1]+google_p1[j+2])
        if j< len(google_p1)-3:
            google_p4.append(google_p1[j]+google_p1[j+1]+google_p1[j+2]+google_p1[j+3])
    # print(google_p2)
    # print(google_p3)
    # print(google_p4)

    # sg
    word = ''
    for j in range(len(sg_text[i])):
        char = sg_text[i][j]
        if 'A' <= char <= 'Z' or 'a' <= char <= 'z' or '0' <= char <= '9':
            word = word + char
            continue
        else:
            if word != '':
                # print(word)
                sg_p1.append(word)
                if char != ' ' and char != '\n':
                    sg_p1.append(char)
                    # print(char)
                word = ''
    print(sg_p1)
    sg_p2 = []
    sg_p3 = []
    sg_p4 = []
    for j in range(len(sg_p1)):
        if j< len(sg_p1)-1:
            sg_p2.append(sg_p1[j]+sg_p1[j+1])
        if j< len(sg_p1)-2:
            sg_p3.append(sg_p1[j]+sg_p1[j+1]+sg_p1[j+2])
        if j< len(sg_p1)-3:
            sg_p4.append(sg_p1[j]+sg_p1[j+1]+sg_p1[j+2]+sg_p1[j+3])
    # print(sg_p2)
    # print(sg_p3)
    # print(sg_p4)

    # jscb
    word = ''
    for j in range(len(jscb_text[i])):
        char = jscb_text[i][j]
        if 'A' <= char <= 'Z' or 'a' <= char <= 'z' or '0' <= char <= '9':
            word = word + char
            continue
        else:
            if word != '':
                # print(word)
                jscb_p1.append(word)
                if char != ' ' and char != '\n':
                    jscb_p1.append(char)
                    # print(char)
                word = ''
    print(jscb_p1)
    jscb_p2 = []
    jscb_p3 = []
    jscb_p4 = []
    for j in range(len(jscb_p1)):
        if j< len(jscb_p1)-1:
            jscb_p2.append(jscb_p1[j]+jscb_p1[j+1])
        if j< len(jscb_p1)-2:
            jscb_p3.append(jscb_p1[j]+jscb_p1[j+1]+jscb_p1[j+2])
        if j< len(jscb_p1)-3:
            jscb_p4.append(jscb_p1[j]+jscb_p1[j+1]+jscb_p1[j+2]+jscb_p1[j+3])
    # print(jscb_p2)
    # print(jscb_p3)
    # print(jscb_p4)

    # ref
    word = ''
    for j in range(len(ref_text[i])):
        char = ref_text[i][j]
        if 'A' <= char <= 'Z' or 'a' <= char <= 'z' or '0' <= char <= '9':
            word = word + char
            continue
        else:
            if word != '':
                # print(word)
                ref_p1.append(word)
                if char != ' ' and char != '\n':
                    ref_p1.append(char)
                    # print(char)
                word = ''
    print(ref_p1)
    ref_p2 = []
    ref_p3 = []
    ref_p4 = []
    for j in range(len(ref_p1)):
        if j< len(ref_p1)-1:
            ref_p2.append(ref_p1[j]+ref_p1[j+1])
        if j< len(ref_p1)-2:
            ref_p3.append(ref_p1[j]+ref_p1[j+1]+ref_p1[j+2])
        if j< len(ref_p1)-3:
            ref_p4.append(ref_p1[j]+ref_p1[j+1]+ref_p1[j+2]+ref_p1[j+3])
    # print(ref_p2)
    # print(ref_p3)
    # print(ref_p4)
    # 计算bleu
    ref_num = len(ref_p1)
    google_set_p1 = set(google_p1)
    google_set_p2 = set(google_p2)
    google_set_p3 = set(google_p3)
    google_set_p4 = set(google_p4)
    sg_set_p1 = set(sg_p1)
    sg_set_p2 = set(sg_p2)
    sg_set_p3 = set(sg_p3)
    sg_set_p4 = set(sg_p4)
    jscb_set_p1 = set(jscb_p1)
    jscb_set_p2 = set(jscb_p2)
    jscb_set_p3 = set(jscb_p3)
    jscb_set_p4 = set(jscb_p4)
    ref_set_p1 = set(ref_p1)
    ref_set_p2 = set(ref_p2)
    ref_set_p3 = set(ref_p3)
    ref_set_p4 = set(ref_p4)

    if len(google_set_p1) > 0:
        google_p1_score = len(google_set_p1 & ref_set_p1) / ref_num
        # print("google_p1_score = ",len(google_set_p1 & ref_set_p1))
        if google_p1_score > 0:
            google_p1_score = math.log(len(google_set_p1 & ref_set_p1) / ref_num,2)
        else:
            google_p1_score = 0
        if ref_num > 1:
            google_p2_score = len(google_set_p2 & ref_set_p2) / (ref_num-1)
            if google_p2_score > 0:
                google_p2_score = math.log(len(google_set_p2 & ref_set_p2) / (ref_num-1),2)
            else:
                google_p2_score = 0
        else:
            google_p2_score = google_p1_score
        if ref_num > 2:
            google_p3_score = len(google_set_p3 & ref_set_p3) / (ref_num-2)
            if google_p3_score > 0:
                google_p3_score = math.log(len(google_set_p3 & ref_set_p3) / (ref_num-2),2)
            else:
                google_p3_score = 0
        else:
            google_p3_score = google_p1_score
        if ref_num > 3:
            google_p4_score = len(google_set_p4 & ref_set_p4) / (ref_num-3)
            if google_p4_score > 0:
                google_p4_score = math.log(len(google_set_p4 & ref_set_p4) / (ref_num-3),2)
            else:
                google_p4_score = 0
        else:
            google_p4_score = google_p1_score
        # print(google_p1_score,google_p2_score,google_p3_score,google_p4_score)
        google_bp = 1
        if len(google_p1) < len(ref_p1):
            google_bp = math.exp(1-len(ref_p1)/len(google_p1))
        google_score.append(google_bp*math.exp((google_p1_score+google_p2_score+google_p3_score+google_p4_score)/4))
    
    if len(sg_set_p1) > 0:
        sg_p1_score = len(sg_set_p1 & ref_set_p1) / ref_num
        if sg_p1_score > 0:
            sg_p1_score = math.log(len(sg_set_p1 & ref_set_p1) / ref_num,2)
        else:
            sg_p1_score = 0
        if ref_num > 1:
            sg_p2_score = len(sg_set_p2 & ref_set_p2) / (ref_num-1)
            if sg_p2_score > 0:
                sg_p2_score = math.log(len(sg_set_p2 & ref_set_p2) / (ref_num-1),2)
            else:
                sg_p2_score = 0
        else:
            sg_p2_score = sg_p1_score
        if ref_num > 2:
            sg_p3_score = len(sg_set_p3 & ref_set_p3) / (ref_num-2)
            if sg_p3_score > 0:
                sg_p3_score = math.log(len(sg_set_p3 & ref_set_p3) / (ref_num-2),2)
            else:
                sg_p3_score = 0
        else:
            sg_p3_score = sg_p1_score
        if ref_num > 3:
            sg_p4_score = len(sg_set_p4 & ref_set_p4) / (ref_num-3)
            if sg_p4_score > 0:
                sg_p4_score = math.log(len(sg_set_p4 & ref_set_p4) / (ref_num-3),2)
            else:
                sg_p4_score = 0
        else:
            sg_p4_score = sg_p1_score
        sg_bp = 1
        if len(sg_p1) < len(ref_p1):
            sg_bp = math.exp(1-len(ref_p1)/len(sg_p1))
        sg_score.append(sg_bp*math.exp((sg_p1_score+sg_p2_score+sg_p3_score+sg_p4_score)/4))
    
    if len(jscb_set_p1) > 0:
        jscb_p1_score = len(jscb_set_p1 & ref_set_p1) / ref_num
        if jscb_p1_score > 0:
            jscb_p1_score = math.log(len(jscb_set_p1 & ref_set_p1) / ref_num,2)
        else:
            jscb_p1_score = 0
        if ref_num > 1:
            jscb_p2_score = len(jscb_set_p2 & ref_set_p2) / (ref_num-1)
            if jscb_p2_score > 0:
                jscb_p2_score = math.log(len(jscb_set_p2 & ref_set_p2) / (ref_num-1),2)
            else:
                jscb_p2_score = 0
        else:
            jscb_p2_score = jscb_p1_score
        if ref_num > 2:
            jscb_p3_score = len(jscb_set_p3 & ref_set_p3) / (ref_num-2)
            if jscb_p3_score > 0:
                jscb_p3_score = math.log(len(jscb_set_p3 & ref_set_p3) / (ref_num-2),2)
            else:
                jscb_p3_score = 0
        else:
            jscb_p3_score = jscb_p1_score
        if ref_num > 3:
            jscb_p4_score = len(jscb_set_p4 & ref_set_p4) / (ref_num-3)
            if jscb_p4_score > 0:
                jscb_p4_score = math.log(len(jscb_set_p4 & ref_set_p4) / (ref_num-3),2)
            else:
                jscb_p4_score = 0
        else:
            jscb_p4_score = jscb_p1_score
        jscb_bp = 1
        if len(jscb_p1) < len(ref_p1):
            jscb_bp = math.exp(1-len(ref_p1)/len(jscb_p1))
        jscb_score.append(jscb_bp*math.exp((jscb_p1_score+jscb_p2_score+jscb_p3_score+jscb_p4_score)/4))
    print(google_score[-1])
    print(sg_score[-1])
    print(jscb_score[-1])
# Out:
# 414
# 414
# 414
# ['Civil', 'rights', 'groups', 'issue', 'travel', 'warning', 'for']
# ['Civil', 'rights', 'groups', 'issued', 'travel', 'warnings', 'against', 'Missouri', '.']
# ['Civil', '-', 'rights', 'groups', 'have', 'issued', 'travel', 'warnings', 'against']
# ['Civil', 'rights', 'group', 'issues', 'travel', 'warning', 'for']
# 0.38603056430513105
# 0.386030564305131
# 0.7366826287887924
# ['Due', 'to', 'discriminatory', 'policies', 'and', 'racist', 'attacks', 'in', 'Missouri', ',', 'the', 'National', 'Association', 'for', 'the', 'Advancement', 'of', 'Colored', 'People', 'NAACP', ')', 'has', 'issued', 'a', 'travel', 'advisory', 'to', 'people', 'of', 'color', 'planning', 'to', 'travel', 'to', 'Missouri', '.']
# ['Due', 'to', 'the', 'discriminatory', 'policies', 'and', 'racist', 'attacks', 'in', 'Missouri', ',', 'the', 'American', 'Association', 'for', 'the', 'Advancement', 'of', 'Colored', 'People', 'NAACP', ')', 'issued', 'a', 'travel', 'warning', 'to', 'colored', 'people', 'who', 'are', 'going', 'to', 'travel', 'to', 'Missouri', '.']
# ['Due', 'to', 'Missouri', "'", 's', 'discriminatory', 'policies', 'and', 'racist', 'attacks', ',', 'the', 'American', 'Association', 'for', 'the', 'Promotion', 'of', 'Colored', 'People', 'NAACP', ')', 'has', 'issued', 'travel', 'warnings', 'to', 'colored', 'people', 'preparing', 'to', 'travel', 'to', 'Missouri', '.']
# ['The', 'National', 'Association', 'for', 'the', 'Advancement', 'of', 'Colored', 'People', 'has', 'put', 'out', 'an', 'alert', 'for', 'people', 'of', 'color', 'traveling', 'to', 'Missouri', 'because', 'of', 'the', 'state', "'", 's', 'discriminatory', 'policies', 'and', 'racist', 'attacks', '.']
# 0.2392541523207821
# 0.17991482644459816
# 0.15455699193831238
# ['The', 'NAACP', 'Missouri', 'Travel', 'Advisory', ',', 'effective', 'August', '28', ',', '2017', ',', 'calls', 'for', 'all', 'African', 'American', 'travelers', ',', 'tourists', ',', 'and', 'Missourians', 'to', 'We', 'are', 'hereby', 'informed', 'with', 'the', 'utmost', 'care', 'and', 'caution', ',', 'the', 'group', "'", 's', 'statement', 'declared', '.']
# ['The', 'NAACP', 'Missouri', 'Travel', 'Consultation', ',', 'which', 'came', 'into', 'effect', 'on', 'August', '28', ',', '2017', ',', 'appealed', 'that', 'all', 'African', '-', 'American', 'travelers', ',', 'tourists', 'and', 'Missouri', 'people', 'should', 'pay', 'special', 'attention', 'and', 'take', 'extremely', 'cautious', 'attitude', 'when', 'traveling', 'in', 'Missouri', 'due', 'to', 'a', 'series', 'of', 'suspicious', 'racial', 'incidents', 'in', 'Missouri', 'recently', ',', 'the', 'group', "'", 's', 'statement', 'declared', '.']
# ['Effective', 'August', '28', ',', '2017', 'NAACP', 'Missouri', 'travel', 'consultation', ',', 'because', 'of', 'the', 'recent', 'series', 'of', 'suspicious', 'racial', 'incidents', ',', 'all', 'African', 'American', 'travelers', ',', 'tourists', 'and', 'Missouri', 'people', 'in', 'Missouri', 'should', 'pay', 'special', 'attention', 'and', 'take', 'extremely', 'cautious', 'attitude', ',', 'hereby', 'inform', ',', 'the', 'group', 'statement', 'declared', '.']
# ['The', 'NAACP', 'Travel', 'Advisory', 'for', 'the', 'state', 'of', 'Missouri', ',', 'effective', 'through', 'August', '28th', ',', '2017', ',', 'calls', 'for', 'African', 'American', 'travelers', ',', 'visitors', 'and', 'Missourians', 'to', 'pay', 'special', 'attention', 'and', 'exercise', 'extreme', 'caution', 'when', 'traveling', 'throughout', 'the', 'state', 'given', 'the', 'series', 'of', 'questionable', ',', 'race', '-', 'based', 'incidents', 'occurring', 'statewide', 'recently', ',', 'and', 'noted', 'therein', ',', 'the', 'group', "'", 's', 'statement', 'reads', '.']
# 0.05937284023793568
# 0.07574511470507032
# 0.02876114553625507
# ['The', 'NAACP', 'pointed', 'to', 'a', 'recently', 'passed', 'Missouri', 'law', 'that', 'makes', 'it', 'harder', 'for', 'people', 'to', 'win', 'discrimination', 'lawsuits', ',', 'as', 'well', 'as', 'the', 'fact', 'that', 'law', 'enforcement', 'in', 'the', 'state', 'has', 'targeted', 'minorities', 'in', 'part', ',', 'prompting', 'the', 'group', 'to', 'issue', 'a', 'travel', 'advisory', '.']
# ['NAACP', 'pointed', 'out', 'that', 'a', 'recent', 'Missouri', 'law', 'made', 'it', 'more', 'difficult', 'for', 'people', 'to', 'win', 'discrimination', 'lawsuits', ',', 'and', 'the', 'state', "'", 's', 'law', 'enforcement', 'also', 'targeted', 'at', 'minority', 'groups', 'to', 'some', 'extent', ',', 'which', 'prompted', 'the', 'organization', 'to', 'issue', 'travel', 'warnings', '.']
# ['NAACP', 'Note', 'that', 'a', 'recent', 'Missouri', 'law', 'has', 'made', 'it', 'harder', 'to', 'win', 'discrimination', 'lawsuits', ',', 'and', 'that', 'state', 'enforcement', 'partly', 'targets', 'minorities', ',', 'prompting', 'the', 'group', 'to', 'issue', 'travel', 'warnings', '.']
# ['A', 'recent', 'Missouri', 'law', 'making', 'it', 'harder', 'for', 'people', 'to', 'win', 'discrimination', 'lawsuits', ',', 'as', 'well', 'as', 'the', 'state', "'", 's', 'law', 'enforcement', 'disproportionately', 'targeting', 'minorities', 'prompted', 'the', 'group', 'to', 'issue', 'the', 'travel', 'alert', ',', 'the', 'NAACP', 'said', '.']
# 0.2777955032967168
# 0.197690171152777
# 0.08110733545851512
# ['Violations', 'of', 'civil', 'rights', 'are', 'happening', 'to', 'people', '.']
# ['Violations', 'of', 'civil', 'rights', 'are', 'happening', 'to', 'people', '.']
# ['Violations', 'of', 'civil', 'rights', 'are', 'happening', 'to', 'people', '.']
# ['You', 'have', 'violations', 'of', 'civil', 'rights', 'that', 'are', 'happening', 'to', 'people', '.']
# 0.20780513028000236
# 0.20780513028000236
# 0.20780513028000236
# ['They', 'were', 'pulled', 'over', 'and', 'questioned', 'because', 'of', 'the', 'color', 'of', 'their', 'skin', ',', 'they', 'were', 'beaten', 'or', 'killed', ',', 'Missouri', 'NAACP', 'President', 'Rod', 'Chappell', 'told', 'The', 'Kansas', 'City', 'Star', '.']
# ['They', 'were', 'stopped', 'for', 'questioning', ',', 'beaten', 'or', 'killed', 'because', 'of', 'their', 'skin', 'color', ',', 'Rod', 'Chapel', ',', 'chairman', 'of', 'Missouri', 'NAACP', ',', 'told', 'The', 'Kansas', 'City', 'Star', '.']
# ['They', 'were', 'stopped', 'and', 'questioned', ',', 'beaten', 'or', 'murdered', 'because', 'of', 'their', 'skin', 'color', ',', 'Missouri', 'NAACP', 'President', 'Rod', 'Chapel', 'told', 'the', 'Kansas', 'City', 'Star', 'The', 'Kansas', 'City', 'Star', ')']
# ['They', "'", 're', 'being', 'pulled', 'over', 'because', 'of', 'their', 'skin', 'color', ',', 'they', "'", 're', 'being', 'beaten', 'up', 'or', 'killed', ',', 'the', 'president', 'of', 'the', 'Missouri', 'NAACP', ',', 'Rod', 'Chapel', ',', 'told', 'The', 'Kansas', 'City', 'Star', '.']
# 0.1088952385081209
# 0.18706394549397304
# 0.09597573667893386
# ['We', "'", 've', 'had', 'an', 'unprecedented', 'number', 'of', 'complaints', '.']
# ['We', 'have', 'received', 'many', 'complaints', 'in', 'an', 'unprecedented', 'number', '.']
# ['We', 'have', 'received', 'many', 'complaints', 'in', 'an', 'unprecedented', 'number', '.']
# ['We', 'are', 'hearing', 'complaints', 'at', 'a', 'rate', 'we', 'haven', "'", 't', 'heard', 'before', '.']
# 0.426629753158362
# 0.3845820551723924
# 0.3845820551723924
# ['It', 'was', 'the', 'first', 'warning', 'of', 'its', 'kind', 'issued', 'by', 'the', 'group', 'against', 'a', 'state', 'in', 'the', 'United', 'States', '.']
# ['This', 'is', 'the', 'first', 'such', 'warning', 'issued', 'by', 'the', 'organization', 'for', 'a', 'state', 'in', 'the', 'United', 'States', '.']
# ['It', 'was', 'the', 'first', 'such', 'warning', 'the', 'group', 'issued', 'in', 'the', 'US', 'against', 'a', 'state', '.']
# ['It', 'is', 'the', 'first', 'such', 'warning', 'that', 'the', 'organization', 'has', 'issued', 'for', 'a', 'state', 'in', 'the', 'US', '.']
# 0.08220095498092202
# 0.29936039144405685
# 0.10448304656614545
# ['The', 'group', 'cited', 'racial', 'slurs', 'against', 'black', 'students', 'at', 'the', 'University', 'of', 'Missouri', 'and', 'the', 'death', 'of', 'Tory', 'Sanders', ',', 'a', '28', '-', 'year', '-', 'old', 'black', 'Tennessee', 'man', '.']
# ['The', 'organization', 'cited', 'the', 'racial', 'defamation', 'of', 'black', 'students', 'by', 'the', 'University', 'of', 'Missouri', 'and', 'the', 'death', 'of', 'Tory', 'Sanders', ',', 'a', '28', '-', 'year', '-', 'old', 'black', 'Tennessee', 'man', '.']
# ['The', 'group', 'cited', 'racial', 'defamation', 'against', 'black', 'students', 'at', 'the', 'University', 'of', 'Missouri', 'and', 'the', 'death', 'of', 'Tony', 'Sanders', ',', 'a', '28', '-', 'year', '-', 'old', 'black', 'man', 'in', 'Tennessee', '.']
# ['The', 'group', 'cited', 'incidents', 'such', 'as', 'racial', 'slurs', 'against', 'black', 'students', 'at', 'the', 'University', 'of', 'Missouri', 'and', 'the', 'death', 'of', 'Tory', 'Sanders', ',', '28', ',', 'a', 'black', 'man', 'from', 'Tennessee', '.']
# 0.46290754056631794
# 0.25135174360847384
# 0.3314356901297611
# ['Earlier', 'this', 'year', ',', 'Sanders', 'died', 'under', 'suspicious', 'circumstances', '.', 'He', 'ran', 'out', 'of', 'fuel', 'while', 'traveling', 'in', 'Missouri', 'and', 'was', 'taken', 'into', 'custody', 'by', 'Missouri', 'police', 'without', 'charge', 'of', 'a', 'crime', '.']
# ['Earlier', 'this', 'year', ',', 'Saunders', 'died', 'under', 'suspicious', 'circumstances', '.', 'He', 'ran', 'out', 'of', 'fuel', 'while', 'traveling', 'in', 'Missouri', 'and', 'was', 'detained', 'by', 'Missouri', 'police', 'without', 'charge', '.']
# ['Sanders', 'died', 'earlier', 'this', 'year', 'in', 'suspicious', 'circumstances', '.', 'He', 'ran', 'out', 'of', 'fuel', 'while', 'traveling', 'in', 'Missouri', 'and', 'was', 'detained', 'by', 'the', 'Missouri', 'State', 'Police', 'without', 'a', 'crime', 'charged', '.']
# ['Sanders', 'died', 'under', 'questionable', 'circumstances', 'earlier', 'this', 'year', 'after', 'he', 'ran', 'out', 'of', 'gas', 'while', 'traveling', 'through', 'the', 'state', ',', 'and', 'was', 'taken', 'into', 'custody', 'by', 'Missouri', 'police', 'without', 'being', 'accused', 'of', 'a', 'crime', '.']
# 0.24880443708632072
# 0.045772039365752894
# 0.1550767336538802
# ['The', 'advisory', 'also', 'noted', 'that', 'a', 'recent', 'report', 'from', 'the', 'Missouri', 'Attorney', 'General', "'", 's', 'Office', 'found', 'that', 'black', 'drivers', 'in', 'the', 'state', 'are', '75', 'percent', 'more', 'likely', 'to', 'be', 'stopped', 'and', 'stopped', 'compared', 'to', 'whites', '.']
# ['The', 'consultation', 'also', 'pointed', 'out', 'that', 'a', 'recent', 'report', 'by', 'the', 'Missouri', 'Attorney', 'General', "'", 's', 'Office', 'showed', 'that', 'compared', 'with', 'whites', ',', 'black', 'drivers', 'in', 'the', 'state', 'are', '75', '%', 'more', 'likely', 'to', 'be', 'stopped', '"']
# ['The', 'consultation', 'also', 'noted', 'that', 'a', 'recent', 'report', 'by', 'the', 'Missouri', 'Attorney', 'General', "'", 's', 'office', 'showed', 'that', 'black', 'drivers', 'in', 'the', 'state', 'are', '75', '%', 'more', 'likely', 'to', 'be', 'stopped', 'and', 'questioned', 'compared', 'to', 'white', 'people', '"']
# ['The', 'advisory', 'also', 'points', 'to', 'a', 'recent', 'report', 'by', 'the', 'Missouri', 'Attorney', 'General', "'", 's', 'Office', 'showing', 'that', 'black', 'drivers', 'in', 'the', 'state', 'were', '75', 'percent', 'more', 'likely', 'to', 'be', 'pulled', 'over', 'than', 'whites', '.']
# 0.3734799203859885
# 0.33943187199138763
# 0.3289449905267937
# ['This', 'advisory', 'is', 'to', 'raise', 'awareness', 'and', 'warn', 'their', 'families', ',', 'friends', 'and', 'colleagues', 'of', 'what', 'may', 'be', 'happening', 'in', 'Missouri', ',', 'Chappell', 'said', '.']
# ['Chapel', 'said', ':', 'The', 'consultation', 'is', 'to', 'raise', 'people', "'", 's', 'awareness', 'and', 'warn', 'their', 'families', ',', 'friends', 'and', 'colleagues', 'of', 'what', 'may', 'happen', 'in', 'Missouri', '.']
# ['Chapperll', 'said', ':', 'This', 'consultation', 'is', 'designed', 'to', 'raise', 'awareness', 'and', 'warn', 'their', 'family', ',', 'friends', 'and', 'colleagues', 'about', 'what', 'might', 'happen', 'in', 'Missouri', '.']
# ['The', 'advisory', 'is', 'for', 'people', 'to', 'be', 'aware', ',', 'and', 'warn', 'their', 'families', 'and', 'friends', 'and', 'co', '-', 'workers', 'of', 'what', 'could', 'happen', 'in', 'Missouri', ',', 'Chapel', 'said', '.']
# 0.06383562181199195
# 0.06956331159325535
# 0.13406052504330174
# ['People', 'need', 'to', 'be', 'prepared', ',', 'whether', 'it', "'", 's', 'going', 'to', 'Missouri', 'with', 'bail', 'or', 'letting', 'relatives', 'know', 'they', "'", 're', 'traveling', 'within', 'the', 'state', ',', 'he', 'said', '.']
# ['People', 'need', 'to', 'be', 'prepared', ',', 'whether', 'they', 'are', 'going', 'to', 'Missouri', 'with', 'bail', 'or', 'letting', 'their', 'relatives', 'know', 'that', 'they', 'are', 'traveling', 'in', 'the', 'state', '.']
# ['People', 'need', 'to', 'be', 'prepared', ',', 'whether', 'to', 'carry', 'bail', 'to', 'Missouri', 'or', 'to', 'let', 'relatives', 'know', 'they', 'are', 'traveling', 'within', 'the', 'state', '"']
# ['People', 'need', 'to', 'be', 'ready', ',', 'whether', 'it', "'", 's', 'bringing', 'bail', 'money', 'with', 'them', ',', 'or', 'letting', 'relatives', 'know', 'they', 'are', 'traveling', 'through', 'the', 'state', '.']
# 0.2556791847216651
# 0.10045220832747069
# 0.12872075259749952
# ['According', 'to', 'the', 'most', 'recent', 'data', 'from', 'the', 'FBI', "'", 's', 'Hate', 'Crime', 'Reporting', 'Program', ',', 'Missouri', 'recorded', '100', 'hate', 'crimes', 'in', '2015', ';', 'the', 'state', 'ranks', '16th', 'in', 'the', 'nation', 'based', 'on', 'crime', 'volume', '.']
# ['According', 'to', 'the', 'latest', 'data', 'from', 'the', 'hate', 'crime', 'reporting', 'program', 'of', 'the', 'FBI', ',', 'Missouri', 'recorded', '100', 'hate', 'crimes', 'in', '2015', ';', 'According', 'to', 'the', 'number', 'of', 'crimes', ',', 'the', 'state', 'ranks', '16th', 'in', 'the', 'country', '.']
# ['According', 'to', 'the', 'latest', 'data', 'from', 'the', 'FBI', 'Hate', 'crime', 'Reporting', 'program', ',', 'Missouri', 'recorded', '100', 'hate', 'crimes', 'in', '2015', ';', 'the', 'state', 'ranks', '16th', 'in', 'the', 'country', 'based', 'on', 'the', 'number', 'of', 'crimes', '.']
# ['Missouri', 'recorded', '100', 'hate', 'crimes', 'in', '2015', ',', 'according', 'to', 'the', 'latest', 'figures', 'from', 'the', 'FBI', "'", 's', 'hate', 'crime', 'reporting', 'program', ',', 'ranking', 'the', 'state', 'at', '16th', 'in', 'the', 'country', 'in', 'terms', 'of', 'the', 'number', 'of', 'such', 'violations', '.']
# 0.1430949256951281
# 0.19941425811268054
# 0.1528763540753772
# ['The', 'travel', 'warning', 'is', 'also', 'a', 'response', 'to', 'a', 'new', 'Missouri', 'law', 'that', 'will', 'make', 'it', 'harder', 'to', 'sue', 'businesses', 'for', 'housing', 'or', 'employment', 'discrimination', '.']
# ['Travel', 'warnings', 'are', 'also', 'a', 'response', 'to', 'Missouri', "'", 's', 'new', 'law', ',', 'which', 'will', 'make', 'it', 'more', 'difficult', 'to', 'sue', 'companies', 'that', 'discriminate', 'against', 'housing', 'or', 'employment', '.']
# ['The', 'travel', 'warning', 'is', 'also', 'a', 'response', 'to', 'a', 'new', 'Missouri', 'law', 'that', 'would', 'make', 'it', 'harder', 'to', 'prosecute', 'housing', 'or', 'employment', 'discrimination', 'against', 'businesses', '.']
# ['The', 'travel', 'warning', 'is', 'also', 'a', 'response', 'to', 'a', 'new', 'Missouri', 'law', 'that', 'would', 'make', 'it', 'more', 'difficult', 'to', 'sue', 'a', 'business', 'for', 'housing', 'or', 'employment', 'discrimination', '.']
# 0.4763207307946924
# 0.18778677816655576
# 0.48250902420595154
# ['The', 'move', 'comes', 'after', 'US', 'states', 'passed', 'immigration', 'enforcement', 'laws', 'requiring', 'local', 'law', 'enforcement', 'to', 'detain', 'immigration', 'violators', ',', 'a', 'move', 'the', 'American', 'Civil', 'Liberties', 'Union', 'ACLU', ')', 'said', 'would', 'increase', 'the', 'number', 'of', 'racial', 'lawsuits', 'and', 'issued', 'travel', 'advisories', 'for', 'Texas', 'and', 'Arizona']
# ['Earlier', ',', 'American', 'states', 'passed', 'immigration', 'enforcement', 'laws', ',', 'requiring', 'local', 'law', 'enforcement', 'agencies', 'to', 'detain', 'immigration', 'offenders', '.', 'The', 'American', 'Civil', 'Liberties', 'Union', 'ACLU', ')', 'said', 'that', 'this', 'move', 'would', 'increase', 'the', 'number', 'of', 'racial', 'lawsuits', 'and', 'issued', 'travel', 'advisories', 'for', 'Texas', 'and', 'Arizona', '.']
# ['After', 'states', 'passed', 'immigration', 'enforcement', 'laws', 'requiring', 'local', 'law', 'enforcement', 'authorities', 'to', 'detain', 'immigration', 'violations', '.', 'The', 'American', 'Civil', 'Liberties', 'Union', 'ACLU', ')', 'said', 'it', 'would', 'increase', 'the', 'number', 'of', 'racial', 'lawsuits', 'and', 'issued', 'travel', 'counseling', 'for', 'Texas', 'and', 'Arizona', '.']
# ['Previously', ',', 'the', 'American', 'Civil', 'Liberties', 'Union', 'ACLU', ')', 'had', 'issued', 'travel', 'advisories', 'for', 'Texas', 'and', 'Arizona', 'after', 'the', 'states', 'passed', 'immigration', 'enforcement', 'laws', 'requiring', 'local', 'law', 'enforcement', 'to', 'detain', 'people', 'on', 'immigration', 'violations', 'which', 'the', 'ACLU', 'said', 'would', 'increase', 'racial', 'profiling', '.']
# 0.39809274570220154
# 0.2766533107599804
# 0.25341499660620187
# ['Travel', 'advisories', 'are', 'usually', 'issued', 'by', 'the', 'U', '.', 'S', '.', 'government', 'for', 'other', 'countries', ',', 'but', 'recently', ',', 'advisory', 'groups', 'have', 'taken', 'this', 'approach', 'in', 'response', 'to', 'certain', 'laws', 'and', 'trends', 'within', 'the', 'U', '.', 'S', '.']
# ['Travel', 'warnings', 'are', 'usually', 'issued', 'by', 'the', 'U', '.', 'S', '.', 'government', 'for', 'other', 'countries', ',', 'but', 'recently', ',', 'advisory', 'groups', 'have', 'adopted', 'this', 'approach', 'to', 'deal', 'with', 'certain', 'laws', 'and', 'trends', 'in', 'the', 'United', 'States', '.']
# ['Travel', 'warnings', 'are', 'usually', 'issued', 'by', 'the', 'U', '.', 'S', '.', 'government', 'against', 'other', 'countries', ',', 'but', 'more', 'recently', ',', 'advisory', 'groups', 'have', 'taken', 'this', 'approach', 'in', 'response', 'to', 'certain', 'laws', 'and', 'trends', 'within', 'the', 'United', 'States', '.']
# ['Travel', 'warnings', 'are', 'usually', 'issued', 'by', 'the', 'State', 'Department', 'for', 'other', 'countries', ',', 'but', 'lately', ',', 'advocacy', 'groups', 'have', 'resorted', 'to', 'the', 'measure', 'in', 'response', 'to', 'certain', 'laws', 'and', 'trends', 'inside', 'the', 'US', '.']
# 0.26398753087304194
# 0.2370997175209337
# 0.29091850967373206
# ['experiencing', 'the', 'golden', 'age', '"', 'of', 'soaring', 'box', 'office', 'in', '2015', ',', 'the', 'overall', 'film', 'market', 'has', 'entered', 'a', 'cooling', '-', 'off', 'period', 'in', '2016', '.', 'Whether', 'it', 'can', 'break', 'through', 'last', 'year', "'", 's', 'total', 'box', 'office', 'of', '44', '.', '069', 'billion', 'yuan', 'has', 'become', 'a', 'suspense', '.']
# ['After', 'experiencing', 'the', 'golden', 'age', '"', 'of', 'box', 'office', 'surge', 'in', '2015', ',', 'the', 'overall', 'film', 'market', 'entered', 'a', 'cooling', '-', 'off', 'period', 'in', '2016', ',', 'and', 'whether', 'it', 'can', 'break', 'through', 'the', 'total', 'box', 'office', 'score', 'of', '44', '.', '069', 'billion', 'yuan', 'last', 'year', 'has', 'become', 'a', 'suspense', '.']
# ['After', 'the', 'golden', 'age', '"', 'of', 'box', 'office', 'surge', 'in', '2015', ',', 'the', 'overall', 'film', 'market', 'entered', 'a', 'cooling', '-', 'off', 'period', 'in', '2016', ',', 'and', 'whether', 'the', 'total', 'box', 'office', 'performance', 'of', '44', '.', '069', 'billion', 'yuan', 'last', 'year', 'has', 'become', 'a', 'suspense', '.']
# ['After', 'experiencing', 'the', 'golden', 'era', '”', 'of', 'a', 'soaring', 'box', 'office', 'in', '2015', ',', 'the', 'film', 'market', 'retreated', 'into', 'a', 'cooling', '-', 'off', 'period', 'in', '2016', '.', 'Whether', 'box', 'office', 'takings', 'could', 'surpass', 'last', 'year', '’', 's', 'total', 'of', 'RMB44', '.', '069', 'billion', 'is', 'questionable', '.']
# 0.24177014530678534
# 0.16034157876845528
# 0.1275298381553262
# ['According', 'to', 'the', 'data', 'released', 'by', 'the', 'National', 'Bureau', 'of', 'Statistics', ',', 'in', 'October', ',', 'the', 'prices', 'of', 'new', 'and', 'second', '-', 'hand', 'housing', 'in', 'Beijing', 'both', 'cooled', 'down', ',', 'rising', 'only', '0', '.', '6', '%', 'and', '1', '.', '1', '%', 'month', '-', 'on', '-', 'month', '.']
# ['According', 'to', 'the', 'data', 'released', 'by', 'the', 'National', 'Bureau', 'of', 'Statistics', ',', 'in', 'October', ',', 'the', 'prices', 'of', 'new', 'houses', 'and', 'second', '-', 'hand', 'houses', 'in', 'Beijing', 'both', 'cooled', 'down', ',', 'up', 'only', '0', '.', '6', '%', 'and', '1', '.', '1', '%', 'from', 'the', 'previous', 'month', '.']
# ['For', 'both', 'new', 'and', 'second', '-', 'hand', 'homes', ',', 'prices', 'cooled', 'in', 'October', ',', 'rising', 'just', '0', '.', '6', 'percent', 'and', '1', '.', '1', 'percent', ',', 'according', 'to', 'the', 'month', '-', 'on', '-', 'month', '.']
# ['Data', 'from', 'the', 'National', 'Bureau', 'of', 'Statistics', 'revealed', 'that', 'in', 'October', ',', 'prices', 'of', 'new', 'and', 'second', '-', 'hand', 'residential', 'properties', 'cooled', ',', 'up', '0', '.', '6', '%', 'and', '1', '.', '1', '%', 'month', '-', 'on', '-', 'month', ',', 'respectively', '.']
# 0.4035578464479276
# 0.2645003690610447
# 0.12979470466871276
# ['Lupescu', ',', 'the', 'current', 'chief', 'technical', 'officer', 'of', 'UEFA', ',', 'made', 'a', 'technical', 'report', 'on', 'the', '2016', 'European', 'Championship', 'and', 'last', 'season', "'", 's', 'UEFA', 'Champions', 'League', 'at', 'this', 'conference', '.']
# ['Lupescu', ',', 'the', 'current', 'chief', 'technical', 'officer', 'of', 'UEFA', ',', 'gave', 'a', 'technical', 'report', 'on', 'the', '2016', 'European', 'Championship', 'and', 'last', 'season', "'", 's', 'Champions', 'League', 'at', 'this', 'conference', '.']
# ['Lupescu', ',', 'now', 'the', 'chief', 'technology', 'officer', 'of', 'UEFA', ',', 'gave', 'a', 'technical', 'report', 'on', 'the', 'Euro', '2016', 'Championship', 'and', 'last', 'season', "'", 's', 'Champions', 'League', '.']
# ['Lupekscu', ',', 'the', 'current', 'Chief', 'Technology', 'Officer', 'of', 'UEFA', ',', 'made', 'a', 'technical', 'report', 'on', 'the', '2016', 'UEFA', 'Euro', 'and', 'the', 'last', 'season', 'of', 'European', 'Champions', 'League', 'at', 'the', 'meeting', '.']
# 0.26303600824854484
# 0.15287452258463816
# 0.07967863045300635
# ['BBC', 'calls', 'Beijing', 'the', 'most', 'exciting', 'city', ':', 'it', 'makes', 'foreigners', 'feel', 'living', 'in', 'a', 'new', 'era', '"']
# ['BBC', 'calls', 'Beijing', 'the', 'most', 'exciting', 'city', ':', 'it', 'makes', 'foreigners', 'feel', 'living', 'in', 'a', 'new', 'era', '"']
# ['The', 'BBC', 'says', 'Beijing', 'is', 'the', 'most', 'exciting', 'city', ':', 'making', 'foreigners', 'feel', 'living', 'in', 'a', 'new', 'era', '"']
# ['BBC', 'claims', 'that', 'Beijing', 'has', 'become', 'the', 'most', 'exciting', 'city', ':', 'making', 'foreigners', 'feel', 'like', 'living', 'in', 'a', 'new', 'age', '”']
# 0.16565323913006236
# 0.16565323913006236
# 0.2982789111876193
# ['Reference', 'News', 'Network', 'reported', 'on', 'January', '18', 'that', 'Beijing', 'may', 'have', 'a', 'long', 'history', 'of', 'three', 'thousand', 'years', ',', 'but', 'it', 'is', 'also', 'rapidly', 'transforming', 'into', 'the', 'modern', 'and', 'charming', 'city', 'it', 'is', 'today', '.']
# ['The', 'reference', 'news', 'network', 'reported', 'on', 'January', '18', 'that', 'British', 'media', 'said', 'that', 'Beijing', 'may', 'have', 'a', 'long', 'history', 'of', '3', ',', '000', 'years', ',', 'but', 'it', 'is', 'also', 'rapidly', 'transforming', 'into', 'today', "'", 's', 'modern', 'charming', 'city', '.']
# ['Beijing', 'may', 'have', 'a', 'long', 'history', 'of', '3', ',', '000', 'years', ',', 'but', 'it', 'is', 'rapidly', 'becoming', 'a', 'modern', 'city', ',', 'according', 'to', 'British', 'media', '.']
# ['Reference', 'News', 'Network', 'reported', 'on', 'January', '18', 'that', 'the', 'British', 'media', 'organization', 'has', 'noticed', 'that', 'Beijing', 'is', 'rapidly', 'transforming', 'into', 'a', 'glamorous', 'modern', 'city', 'in', 'spite', 'of', 'the', 'fact', 'that', 'it', 'is', '3000', 'years', 'old', '.']
# 0.15090879085680275
# 0.08181430965397513
# 0.20946957769477625
# ['With', 'its', 'blazingly', 'fast', 'internet', ',', 'cutting', '-', 'edge', 'technology', 'like', 'facial', 'recognition', 'software', ',', 'huge', 'investments', 'in', 'artificial', 'intelligence', 'and', 'an', 'unrivaled', 'cosmopolitan', 'energy', ',', 'the', 'Chinese', 'capital', 'is', 'an', 'ideal', 'destination', 'for', 'inquisitive', 'foreigners', '.', 'One', 'of', 'the', 'most', 'exciting', 'cities', '.']
# ['The', 'capital', 'of', 'China', 'is', 'one', 'of', 'the', 'most', 'exciting', 'cities', 'for', 'foreigners', 'who', 'are', 'full', 'of', 'exploration', 'spirit', ',', 'with', 'the', 'amazing', 'speed', 'of', 'Internet', ',', 'cutting', '-', 'edge', 'technologies', 'such', 'as', 'face', 'recognition', 'software', ',', 'huge', 'investment', 'in', 'artificial', 'intelligence', 'and', 'unparalleled', 'international', 'energy', '.']
# ['The', 'Chinese', 'capital', ',', 'with', 'its', 'amazingly', 'fast', 'Internet', 'and', 'cutting', '-', 'edge', 'technologies', 'such', 'as', 'facial', 'recognition', 'software', ',', 'has', 'invested', 'heavily', 'in', 'artificial', 'intelligence', 'and', 'has', 'unrivaled', 'international', 'energy', ',', 'and', 'is', 'one', 'of', 'the', 'most', 'exciting', 'cities', 'for', 'exploratory', 'foreigners', '.']
# ['The', 'Chinese', 'capital', 'is', 'interconnected', 'by', 'amazingly', 'high', '-', 'speed', 'Internet', 'and', 'has', 'implemented', 'cutting', '-', 'edge', 'technologies', 'such', 'as', 'face', 'recognition', '.', 'It', 'has', 'invested', 'heavily', 'in', 'artificial', 'intelligence', 'and', 'has', 'an', 'unmatched', 'capacity', 'of', 'internationalization', '.', 'It', 'is', 'one', 'of', 'the', 'most', 'exciting', 'cities', 'for', 'foreigners', 'who', 'are', 'eager', 'to', 'explore', 'the', 'world', '.']
# 0.049927234840377664
# 0.18207350228671074
# 0.17131023481894753
# ['If', 'I', 'can', 'succeed', 'there', ',', 'I', 'can', 'succeed', 'everywhere', ',', 'said', 'German', 'expat', 'Clemens', 'Seich', ',', 'citing', 'singer', 'Frank', 'Sinnert', ',', 'according', 'to', 'the', 'BBC', 'website', 'on', 'January', '16', 'La', 'sings', 'the', 'lyrics', 'to', 'New', 'York', 'City', '.']
# ['According', 'to', 'a', 'report', 'on', 'the', 'BBC', 'website', 'on', 'January', '16th', ',', 'Clemens', 'Sethi', ',', 'a', 'German', 'national', ',', 'said', ',', 'If', 'I', 'can', 'succeed', 'there', ',', 'I', 'can', 'succeed', 'anywhere', 'in', 'the', 'future', '.', 'He', 'quoted', 'the', 'singer', 'Frank', 'sinatra', "'", 's', 'lyrics', 'praising', 'new', 'york', 'City', '.']
# ['According', 'to', 'the', 'BBC', 'website', 'on', 'January', '16', ',', 'German', 'expatriate', 'Klemens', 'Cesh', 'said', ':', 'If', 'I', 'can', 'succeed', 'there', ',', 'I', 'will', 'succeed', 'anywhere', 'later', '.', 'He', 'quotes', 'lyrics', 'from', 'singer', 'Frank', 'Sinatra', 'about', 'New', 'York', 'City', '.']
# ['According', 'to', 'a', 'report', 'on', 'the', 'BBC', 'website', 'on', 'January', '16', ',', 'the', 'German', 'expatriate', 'Clemens', 'Sage', 'said', ':', 'If', 'I', 'can', 'succeed', 'there', ',', 'I', 'can', 'succeed', 'anywhere', '.', 'He', 'quoted', 'a', 'song', 'written', 'by', 'singer', 'Frank', 'Sinatra', 'to', 'praise', 'New', 'York', 'City', '.']
# 0.16897412631722253
# 0.2867392761923016
# 0.23808680168465388
# ['If', 'Sinatra', 'were', 'alive', 'today', ',', 'he', 'would', 'probably', 'be', 'singing', 'about', 'a', 'city', 'like', 'Beijing', ',', 'said', 'Sehi', ',', 'creative', 'director', 'at', 'Traveller', "'", 's', 'Archives', 'magazine', '.', 'Living', 'in', 'the', 'city', ',', 'he', 'says', ',', 'makes', 'you', 'feel', 'lived', '.', 'In', 'the', 'new', 'era', '"', 'always', 'keep', 'up', 'with', 'the', 'trend', '.']
# ['Sethi', ',', 'the', 'creative', 'director', 'of', 'Traveler', "'", 's', 'Archives', 'magazine', ',', 'said', ':', 'If', 'sinatra', 'were', 'alive', 'today', ',', 'he', 'would', 'probably', 'sing', 'about', 'a', 'city', 'like', 'Beijing', '.', 'He', 'said', 'that', 'living', 'in', 'this', 'city', 'will', 'make', 'you', 'feel', 'living', 'in', 'a', 'new', 'era', '"', 'and', 'always', 'keep', 'up', 'with', 'the', 'trend', '.']
# ['Sy', ',', 'creative', 'director', 'at', 'Travelers', 'Archives', 'magazine', ',', 'said', ':', 'If', 'Sinatra', 'lived', 'to', 'this', 'day', ',', 'he', 'would', 'probably', 'sing', 'about', 'cities', 'like', 'Beijing', '.', 'Living', 'in', 'the', 'city', 'makes', 'you', 'feel', '"', 'living', 'in', 'a', 'new', 'age', 'and', 'always', 'keeping', 'up', 'with', 'trends', '.']
# ['Sage', ',', 'who', 'served', 'as', 'Creative', 'Director', 'of', 'Traveler', 'Archives', ',', 'said', ':', 'If', 'Sinatra', 'lives', 'today', ',', 'he', 'is', 'likely', 'to', 'sing', 'a', 'song', 'for', 'Beijing', '.', 'He', 'said', 'that', 'living', 'in', 'this', 'city', 'will', 'make', 'you', 'feel', 'like', 'living', 'in', 'a', 'new', 'age', '”', 'which', 'means', 'that', 'you', 'can', 'always', 'keep', 'up', 'with', 'the', 'trends', '.']
# 0.038642217628704956
# 0.22590110074601769
# 0.06035699202971558
# ['in', 'Beijing', ',', 'wrote', 'on', 'his', 'personal', 'blog', '4Corners7Seas', ':', 'There', 'is', 'a', 'general', 'sense', 'of', 'being', 'at', 'the', 'center', 'of', 'something', 'big', ',', 'which', 'is', 'hard', 'to', 'articulate', ',', 'but', 'it', 'makes', 'many', 'foreign', 'People', 'stay', 'there', 'for', 'a', 'long', 'time', '.', 'They', 'want', 'to', 'see', 'what', 'it', "'", 's', 'going', 'to', 'be', 'like', ',', 'and', 'they', 'want', 'to', 'see', 'it', 'for', 'themselves', '.']
# ['Simon', 'Norton', ',', 'whose', 'hometown', 'is', 'in', 'England', ',', 'but', 'recently', 'lives', 'in', 'Beijing', ',', 'said', 'in', 'an', 'article', 'on', 'his', 'personal', 'blog', 'site', '4Corners7Seas', ':', 'People', 'generally', 'have', 'a', 'feeling', 'of', 'being', 'at', 'the', 'center', 'of', 'something', 'grand', ',', 'which', 'is', 'hard', 'to', 'say', 'clearly', ',', 'but', 'it', 'keeps', 'many', 'foreigners', 'there', 'for', 'a', 'long', 'time', '.', 'They', 'want', 'to', 'see', 'what', 'it', 'will', 'become', 'and', 'hope', 'to', 'witness', 'it', 'with', 'their', 'own', 'eyes', '.']
# ['Simon', 'Norton', ',', 'who', 'lives', 'in', 'England', 'but', 'recently', 'lived', 'in', 'Beijing', ',', 'wrote', 'on', 'Corners7Seas', ':', 'People', 'generally', 'have', 'a', 'sense', 'of', 'being', 'at', 'the', 'center', 'of', 'something', 'grand', ',', 'which', 'is', 'hard', 'to', 'explain', ',', 'but', 'it', 'keeps', 'many', 'foreigners', 'there', 'for', 'a', 'long', 'time', '.', 'They', 'want', 'to', 'see', 'what', 'it', 'will', 'like', 'and', 'want', 'to', 'witness', 'it', '.']
# ['Simon', 'Norton', ',', 'who', 'originates', 'from', 'England', 'had', 'been', 'living', 'in', 'Beijing', 'in', 'recent', 'years', ',', 'published', 'an', 'article', 'on', 'personal', 'blog', 'site', '4Corners7Seas', 'saying', ':', 'People', 'generally', 'have', 'a', 'feeling', 'of', 'being', 'at', 'the', 'center', 'of', 'something', 'grand', '.', 'Although', 'this', 'feeling', 'is', 'hard', 'to', 'describe', 'clearly', ',', 'it', 'is', 'the', 'reason', 'why', 'so', 'many', 'foreigners', 'stay', 'there', 'for', 'a', 'long', 'time', '.', 'They', 'want', 'to', 'see', 'what', 'it', 'will', 'become', 'and', 'hope', 'to', 'witness', 'it', '.']
# 0.12019120907296253
# 0.34485484558309293
# 0.1791965693282623
# ['The', 'city', "'", 's', 'high', '-', 'quality', ',', 'high', '-', 'speed', 'internet', 'and', 'technology', '-', 'friendly', 'environment', 'make', 'everyday', 'life', 'easier', 'than', 'ever', '.']
# ['According', 'to', 'the', 'report', ',', 'the', 'city', "'", 's', 'high', '-', 'quality', 'and', 'high', '-', 'speed', 'Internet', 'and', 'technology', '-', 'friendly', 'environment', 'make', 'daily', 'life', 'easier', 'than', 'ever', '.']
# ['The', 'city', "'", 's', 'quality', ',', 'high', '-', 'speed', 'Internet', 'and', 'technology', '-', 'friendly', 'environment', 'make', 'daily', 'life', 'easier', 'than', 'ever', 'before', ',', 'the', 'report', 'said', '.']
# ['According', 'to', 'reports', ',', 'the', 'city', "'", 's', 'high', '-', 'quality', ',', 'high', '-', 'speed', 'Internet', 'and', 'technology', '-', 'friendly', 'environment', 'make', 'everyday', 'life', 'easier', 'than', 'ever', 'before', '.']
# 0.41252947147086094
# 0.507521567304758
# 0.40779828872156676
# ['Beijing', 'is', 'rapidly', 'transforming', 'into', 'a', 'cashless', 'society', ',', 'with', 'the', 'Internet', 'integrating', 'the', 'functions', 'of', 'traditional', 'wallets', 'into', 'smartphones', ',', 'said', 'Andy', 'Penafuerte', ',', 'who', 'is', 'from', 'Manila', 'and', 'is', 'currently', 'deputy', 'editor', '-', 'in', '-', 'chief', 'of', 'Beijing', 'Kids', '.', 'com', '.', 'Making', 'many', 'transactions', 'easier', 'for', 'everyone', '.']
# ['Andy', 'Pe', 'ñ', 'a', 'Fuerte', ',', 'from', 'Manila', ',', 'who', 'is', 'currently', 'the', 'deputy', 'editor', '-', 'in', '-', 'chief', 'of', 'Beijing', 'Children', "'", 's', 'website', ',', 'said', ':', 'Beijing', 'is', 'rapidly', 'transforming', 'into', 'a', 'cashless', 'society', '.', 'The', 'Internet', 'integrates', 'the', 'functions', 'of', 'traditional', 'wallets', 'into', 'smart', 'phones', ',', 'making', 'it', 'easier', 'for', 'everyone', 'to', 'make', 'many', 'transactions', '.']
# ['Andy', 'PeniFuert', ',', 'from', 'Manila', 'and', 'currently', 'deputy', 'editor', '-', 'in', '-', 'chief', 'at', 'Beijing', 'Children', ',', 'said', ':', 'Beijing', 'is', 'rapidly', 'transforming', 'into', 'a', 'cashless', 'society', ',', 'with', 'the', 'Internet', 'integrating', 'the', 'features', 'of', 'traditional', 'wallets', 'into', 'smartphones', 'and', 'making', 'it', 'easier', 'for', 'everyone', 'to', 'make', 'many', 'transactions', '.']
# ['Andy', 'Pe', 'ñ', 'afuerte', ',', 'who', 'originates', 'from', 'Manila', 'and', 'is', 'currently', 'the', 'deputy', 'editor', '-', 'in', '-', 'chief', 'of', 'the', 'website', 'Beijing', 'Children', ',', 'said', ':', 'Beijing', 'is', 'rapidly', 'transforming', 'into', 'a', 'cashless', 'society', '.', 'The', 'Internet', 'integrates', 'the', 'functions', 'of', 'traditional', 'wallets', 'into', 'smart', 'phones', ',', 'making', 'it', 'easier', 'for', 'everyone', 'to', 'conduct', 'various', 'transactions', '.']
# 0.21910137104704785
# 0.5920031837455826
# 0.2569141461692704
# ['But', 'smartphones', 'are', 'just', 'the', 'beginning', 'of', 'Beijing', "'", 's', 'technological', 'ambitions', ',', 'with', 'facial', 'recognition', 'software', 'already', 'ubiquitous', 'and', 'used', 'by', 'many', 'mobile', 'apps', 'to', 'make', 'bank', 'transfers', 'and', 'payments', ',', 'let', 'people', 'into', 'apartments', 'and', 'offices', 'and', 'even', 'verify', 'ride', '-', 'hailing', 'services', 'The', 'identity', 'of', 'the', 'driver', '.']
# ['According', 'to', 'the', 'report', ',', 'however', ',', 'smart', 'phones', 'are', 'only', 'the', 'beginning', 'of', 'Beijing', "'", 's', 'technological', 'ambition', ',', 'and', 'facial', 'recognition', 'software', 'has', 'become', 'very', 'popular', '.', 'Many', 'mobile', 'phone', 'applications', 'use', 'this', 'technology', 'to', 'make', 'bank', 'transfers', 'and', 'payments', ',', 'let', 'people', 'enter', 'apartments', 'and', 'offices', ',', 'and', 'even', 'use', 'it', 'to', 'verify', 'the', 'identity', 'of', 'online', 'car', 'drivers', '.']
# ['But', 'smartphones', 'are', 'just', 'the', 'beginning', 'of', 'Beijing', "'", 's', 'technological', 'ambitions', ',', 'which', 'facial', 'recognition', 'software', 'is', 'so', 'popular', 'that', 'many', 'use', 'to', 'make', 'bank', 'transfers', 'and', 'payments', ',', 'get', 'people', 'to', 'apartments', 'and', 'offices', ',', 'and', 'even', 'to', 'verify', 'the', 'identity', 'of', 'ride', '-', 'hailing', 'drivers', ',', 'the', 'report', 'said', '.']
# ['According', 'to', 'reports', ',', 'smart', 'phones', 'are', 'just', 'the', 'beginning', 'of', 'Beijing', "'", 's', 'technical', 'ambitions', '.', 'Face', 'recognition', 'technology', 'is', 'being', 'widely', 'used', 'across', 'the', 'city', '.', 'Many', 'mobile', 'phone', 'applications', 'use', 'this', 'technology', 'to', 'facilitate', 'bank', 'transfers', 'and', 'payments', ',', 'grant', 'people', 'access', 'apartments', 'and', 'offices', ',', 'and', 'even', 'use', 'it', 'to', 'verify', 'identity', 'of', 'the', 'drivers', 'providing', 'car', '-', 'hailing', 'service', '.']
# 0.08326836327022587
# 0.2721043213002847
# 0.11130695388112734
# ['Beijing', 'also', 'recently', 'announced', 'plans', 'to', 'spend', '13', '.', '8', 'billion', 'yuan', 'to', 'build', 'an', 'artificial', 'intelligence', 'science', 'and', 'technology', 'park', 'that', 'will', 'house', 'more', 'than', '400', 'companies', 'focused', 'on', 'developing', 'AI', 'technologies', 'ranging', 'from', 'biometrics', 'to', 'self', '-', 'driving', 'cars', '.']
# ['Beijing', 'also', 'recently', 'announced', 'plans', 'to', 'spend', '13', '.', '8', 'billion', 'yuan', 'to', 'build', 'an', 'artificial', 'intelligence', 'science', 'and', 'technology', 'park', '.', 'After', 'completion', ',', 'more', 'than', '400', 'enterprises', 'will', 'settle', 'there', ',', 'and', 'they', 'will', 'focus', 'on', 'developing', 'various', 'artificial', 'intelligence', 'technologies', 'from', 'biometrics', 'to', 'self', '-', 'driving', 'cars', '.']
# ['Beijing', 'also', 'recently', 'announced', 'plans', 'to', 'spend', '13', '.', '8', 'billion', 'yuan', 'to', 'build', 'an', 'AI', 'technology', 'park', ',', 'where', 'more', 'than', '400', 'companies', 'will', 'focus', 'on', 'developing', 'AI', 'technologies', 'ranging', 'from', 'biometry', 'to', 'self', '-', 'driving', 'cars', '.']
# ['Beijing', 'recently', 'announced', 'plans', 'to', 'invest', '13', '.', '8', 'billion', 'yuan', 'in', 'the', 'construction', 'of', 'an', 'artificial', 'intelligence', 'technology', 'park', '.', 'When', 'it', 'is', 'completed', ',', 'more', 'than', '400', 'companies', 'will', 'settle', 'there', '.', 'They', 'will', 'focus', 'on', 'the', 'development', 'of', 'artificial', 'intelligence', 'technologies', 'ranging', 'from', 'biometrics', 'to', 'self', '-', 'driving', 'cars', '.']
# 0.17310548508637116
# 0.22837766281092475
# 0.12959021902948636
# ['Food', 'is', 'also', 'at', 'the', 'heart', 'of', 'many', 'major', 'festivals', 'in', 'China', 'over', 'the', 'years', '.', 'Participation', 'in', 'these', 'celebrations', 'is', 'highly', 'regarded', 'by', 'foreigners', '.', 'The', 'Spring', 'Festival', 'is', 'the', 'most', 'important', 'social', 'and', 'economic', 'festival', ',', 'and', 'it', 'is', 'also', 'one', 'of', 'the', 'easiest', 'festivals', 'for', 'foreigners', 'to', 'participate', 'in', '.']
# ['Food', 'is', 'also', 'the', 'core', 'of', 'many', 'major', 'festivals', 'in', 'China', 'over', 'the', 'years', '.', 'Participating', 'in', 'these', 'celebrations', 'is', 'highly', 'respected', 'by', 'foreigners', '.', 'The', 'Spring', 'Festival', 'is', 'the', 'most', 'important', 'social', 'and', 'economic', 'festival', ',', 'and', 'it', 'is', 'also', 'one', 'of', 'the', 'easiest', 'festivals', 'for', 'foreigners', 'to', 'participate', 'in', '.']
# ['Food', 'is', 'also', 'the', 'core', 'of', 'many', 'major', 'festivals', 'in', 'China', 'over', 'the', 'years', '.', 'Participating', 'in', 'these', 'celebrations', 'is', 'highly', 'praised', 'by', 'foreigners', '.', 'The', 'Spring', 'Festival', 'is', 'the', 'most', 'important', 'social', 'and', 'economic', 'festival', ',', 'and', 'also', 'one', 'of', 'the', 'most', 'easy', 'festivals', 'for', 'foreigners', 'to', 'participate', 'in', '.']
# ['Food', 'plays', 'a', 'central', 'role', 'in', 'China', '’', 's', 'many', 'major', 'traditional', 'festivals', '.', 'Foreigners', 'are', 'enthusiastic', 'about', 'these', 'festivals', '.', 'The', 'Spring', 'Festival', 'is', 'the', 'most', 'important', 'festival', 'in', 'both', 'social', 'and', 'economic', 'sense', ',', 'and', 'it', 'is', 'also', 'one', 'of', 'the', 'most', 'enjoyable', 'festivals', 'for', 'foreigners', '.']
# 0.22004004011292833
# 0.22004004011292833
# 0.16866964723512012
# ['Sai', 'Xi', 'said', ':', 'I', 'suggest', 'helping', 'Chinese', 'friends', 'prepare', 'for', 'the', 'New', 'Year', '.', 'Cleaning', 'the', 'apartment', 'is', 'as', 'important', 'as', 'pasting', 'red', 'Spring', 'Festival', 'couplets', 'with', 'New', 'Year', 'greetings', 'on', 'the', 'door', 'of', 'the', 'house', '.', 'On', 'New', 'Year', "'", 's', 'Eve', ',', 'all', 'family', 'members', 'have', 'to', 'gather', 'together', 'for', 'a', 'big', 'meal', '.', 'It', '’', 's', 'a', 'big', 'meal', ',', 'and', 'then', 'watch', 'until', 'midnight', 'to', 'welcome', 'the', 'New', 'Year', 'with', 'brilliant', 'and', 'loud', 'fireworks', '.', 'For', 'foreigners', ',', 'spending', 'this', 'evening', 'with', 'friends', 'and', 'family', 'is', 'really', 'a', 'chance', 'to', 'blend', 'in', '.']
# ['Sethi', 'said', ':', 'I', 'suggest', 'that', 'it', 'is', 'as', 'important', 'to', 'help', 'China', 'friends', 'prepare', 'for', 'the', 'Chinese', 'New', 'Year', '.', 'Cleaning', 'the', 'apartment', 'is', 'as', 'important', 'as', 'putting', 'up', 'red', 'Spring', 'Festival', 'couplets', 'with', 'New', 'Year', 'greetings', 'on', 'their', 'homes', '.', 'On', 'New', 'Year', "'", 's', 'Eve', ',', 'all', 'family', 'members', 'should', 'gather', 'together', 'to', 'have', 'a', 'big', 'meal', ',', 'and', 'then', 'stay', 'up', 'until', 'midnight', 'to', 'welcome', 'the', 'New', 'Year', 'with', 'gorgeous', 'and', 'loud', 'fireworks', '.', 'For', 'foreigners', ',', 'spending', 'the', 'night', 'with', 'friends', 'and', 'family', 'is', 'indeed', 'an', 'opportunity', 'to', 'integrate', '.']
# ['I', 'suggest', 'helping', 'Chinese', 'friends', 'prepare', 'for', 'the', 'Spring', 'Festival', '.', 'Cleaning', 'up', 'the', 'apartment', 'is', 'as', 'important', 'as', 'pasting', 'red', 'Spring', 'Festival', 'couplets', 'with', 'New', 'Year', 'greetings', 'on', 'the', 'door', '.', 'On', 'the', 'New', 'Year', "'", 's', 'Eve', ',', 'all', 'family', 'members', 'should', 'have', 'a', 'big', 'meal', ',', 'and', 'then', 'stay', 'up', 'until', 'midnight', 'to', 'welcome', 'the', 'New', 'Year', 'with', 'loud', 'fireworks', '.', 'For', 'foreigners', ',', 'spending', 'the', 'night', 'with', 'friends', 'and', 'family', 'is', 'indeed', 'an', 'opportunity', 'to', 'join', 'in', '.']
# ['Sage', 'said', ':', 'It', "'", 's', 'a', 'pleasure', 'for', 'me', 'to', 'help', 'Chinese', 'friends', 'prepare', 'for', 'the', 'New', 'Year', '.', 'It', 'is', 'equally', 'important', 'to', 'clean', 'the', 'apartment', 'and', 'paste', 'the', 'red', 'spring', 'couplets', 'with', 'blessing', 'words', 'on', 'the', 'door', '.', 'On', 'New', 'Year', '’', 's', 'eve', ',', 'all', 'family', 'members', 'must', 'gather', 'together', 'to', 'have', 'a', 'good', 'meal', 'and', 'stay', 'until', 'midnight', ',', 'and', 'finally', 'to', 'celebrate', 'the', 'New', 'Year', 'with', 'fireworks', '.', 'For', 'foreigners', ',', 'spending', 'the', 'night', 'with', 'friends', 'and', 'their', 'family', 'is', 'indeed', 'an', 'opportunity', 'for', 'blending', '.']
# 0.13246568975217446
# 0.18699837113239562
# 0.14754636247705893
# ['The', 'number', 'of', 'foreigners', 'in', 'Beijing', 'is', 'large', 'and', 'growing', ',', 'but', 'China', "'", 's', 'language', 'barrier', 'and', 'ease', 'of', 'communication', 'among', 'expatriates', 'can', 'easily', 'be', 'an', 'excuse', 'for', 'them', 'not', 'to', 'fully', 'assimilate', 'into', 'the', 'local', 'culture', '.']
# ['According', 'to', 'the', 'report', ',', 'the', 'number', 'of', 'foreigners', 'in', 'Beijing', 'is', 'large', 'and', 'growing', ',', 'but', 'the', 'language', 'barrier', 'in', 'China', 'and', 'the', 'convenience', 'of', 'communication', 'between', 'expatriates', 'can', 'easily', 'become', 'an', 'excuse', 'for', 'them', 'not', 'to', 'fully', 'integrate', 'into', 'the', 'local', 'culture', '.']
# ['The', 'number', 'of', 'large', 'and', 'growing', 'foreigners', 'in', 'Beijing', ',', 'but', 'China', "'", 's', 'language', 'barrier', 'and', 'the', 'convenience', 'of', 'communication', 'between', 'expatriates', 'are', 'easily', 'an', 'excuse', 'for', 'not', 'being', 'fully', 'integrated', 'into', 'the', 'local', 'culture', ',', 'the', 'report', 'said', '.']
# ['According', 'to', 'reports', ',', 'a', 'large', 'number', 'of', 'foreigners', 'are', 'living', 'in', 'Beijing', 'and', 'the', 'number', 'is', 'growing', '.', 'However', ',', 'the', 'language', 'barrier', 'and', 'the', 'convenience', 'of', 'exchanges', 'between', 'the', 'expatriates', 'can', 'easily', 'become', 'excuses', 'for', 'not', 'fully', 'integrating', 'into', 'the', 'local', 'culture', '.']
# 0.06795063985057093
# 0.14872363531038577
# 0.09524470822792627
# ['Some', 'foreigners', 'have', 'lived', 'in', 'China', 'for', 'years', 'but', 'have', 'little', 'experience', 'with', 'their', 'host', 'country', ',', 'Sehi', 'said', '.', 'If', 'your', 'initial', 'attempts', 'at', 'reaching', 'out', 'to', 'the', 'Chinese', 'are', 'not', 'successful', ',', 'it', "'", 's', 'easy', 'to', 'get', 'along', 'with', 'other', 'foreigners', '.', 'Feel', '.']
# ['Sethi', 'said', ':', 'Some', 'foreigners', 'have', 'lived', 'in', 'China', 'for', 'many', 'years', ',', 'but', 'they', 'have', 'little', 'experience', 'with', 'their', 'host', 'country', '.', 'If', 'your', 'initial', 'attempt', 'to', 'get', 'in', 'touch', 'with', 'China', 'people', 'is', 'not', 'successful', ',', 'it', 'is', 'easy', 'for', 'you', 'to', 'feel', 'that', 'it', 'is', 'easier', 'to', 'get', 'along', 'with', 'other', 'foreigners', '.']
# ['Some', 'foreigners', 'have', 'lived', 'for', 'years', 'in', 'China', ',', 'but', 'they', 'have', 'little', 'experience', 'with', 'their', 'host', 'country', '.', 'If', 'your', 'initial', 'attempt', 'to', 'reach', 'Chinese', 'is', 'not', 'successful', ',', 'it', 'is', 'easy', 'to', 'feel', 'easier', 'to', 'get', 'along', 'with', 'other', 'foreigners', '.']
# ['Sage', 'said', ':', 'Some', 'foreigners', 'have', 'lived', 'in', 'China', 'for', 'many', 'years', ',', 'but', 'they', 'have', 'little', 'experience', 'with', 'their', 'host', 'country', '.', 'If', 'your', 'initial', 'attempt', 'to', 'interact', 'with', 'the', 'Chinese', 'is', 'not', 'successful', ',', 'then', 'it', 'is', 'easy', 'for', 'you', 'to', 'feel', 'more', 'comfortable', 'with', 'other', 'foreigners', '.']
# 0.21361501985273074
# 0.5962510959655088
# 0.30957586278205124
# ['In', 'these', 'so', '-', 'called', 'laowai', 'bubbles', '"', 'laowai', 'bubbles', '"', 'means', 'that', 'foreigners', 'only', 'hang', 'out', 'among', 'foreigners', ',', 'without', 'contact', 'with', 'local', 'people', 'and', 'local', 'culture', '-', 'translator', "'", 's', 'note', ')', 'foreigners', 'live', 'in', 'their', 'own', 'communities', 'Hang', 'out', 'in', 'groups', ',', 'eat', 'at', 'western', 'restaurants', ',', 'and', 'have', 'only', 'foreigners', 'among', 'your', 'friends', '.']
# ['In', 'these', 'so', '-', 'called', 'foreigners', "'", 'bubbles', '"', 'foreigners', "'", 'bubbles', '"', 'means', 'that', 'foreigners', 'only', 'mix', 'among', 'foreigners', ',', 'but', 'not', 'contact', 'with', 'local', 'people', 'and', 'local', 'culture', ')', 'foreigners', 'gather', 'in', 'their', 'own', 'communities', ',', 'eat', 'in', 'western', 'restaurants', ',', 'and', 'only', 'foreigners', 'are', 'among', 'their', 'friends', '.']
# ...
# ['We', 'should', 'accurately', 'grasp', 'the', 'requirements', 'of', 'building', 'a', 'socialist', 'participating', 'political', 'party', 'with', 'Chinese', 'characteristics', ',', 'and', 'earnestly', 'perform', 'our', 'functions', 'of', 'participating', 'in', 'the', 'deliberation', 'and', 'administration', 'of', 'state', 'affairs', ',', 'exercising', 'democratic', 'supervision', ',', 'and', 'participating', 'in', 'the', 'political', 'consultation', 'under', 'the', 'leadership', 'of', 'the', 'CPC', '.']
# ['accurately', 'grasp', 'the', 'requirements', 'of', 'building', 'socialist', 'participating', 'parties', 'with', 'Chinese', 'characteristics', ',', 'earnestly', 'perform', 'the', 'functions', 'of', 'participating', 'in', 'politics', 'and', 'discussing', 'politics', ',', 'supervising', 'democratically', 'and', 'participating', 'in', 'the', 'political', 'consultation', 'under', 'the', 'leadership', 'of', 'the', 'Communist', 'Party', 'of', 'China', '.']
# 0.2860604018548603
# 0.22222481900320246
# 0.30185028786229723
# ['Promote', 'self', '-', 'construction', 'to', 'a', 'new']
# ['Promote', 'self', '-', 'construction', 'to', 'a', 'new']
# ['We', 'will', 'take', 'our', 'self', '-', 'development', 'to', 'a', 'new']
# ['and', 'promote', 'a', 'new', 'level', 'of', 'self', '-', 'building', '.']
# 0.27211385855259496
# 0.27211385855259496
# 0.41771191856979295
# ['Zhang', 'Baowen', ',', 'vice', 'chairman', 'of', 'the', 'Standing', 'Committee', 'of', 'the', 'National', 'People', "'", 's', 'Congress', 'and', 'chairman', 'of', 'the', 'Central', 'Committee', 'of', 'the', 'Democratic', 'League', ',', 'delivered', 'a', 'congratulatory', 'speech', 'on', 'behalf', 'of', 'the', 'central', 'committees', 'of', 'the', 'democratic', 'parties', 'and', 'the', 'All', '-', 'China', 'Federation', 'of', 'Industry', 'and', 'Commerce', '.']
# ['Zhang', 'Baowen', ',', 'Vice', 'Chairman', 'of', 'the', 'National', 'People', "'", 's', 'Congress', 'Standing', 'Committee', 'NPCSC', ')', 'and', 'Chairman', 'of', 'the', 'NLD', 'Central', 'Committee', ',', 'delivered', 'a', 'congratulatory', 'message', 'on', 'behalf', 'of', 'the', 'central', 'committees', 'of', 'democratic', 'parties', 'and', 'the', 'All', '-', 'China', 'Federation', 'of', 'Industry', 'and', 'Commerce', '.']
# ['Zhang', 'Baowen', ',', 'vice', 'chairman', 'of', 'the', 'Standing', 'Committee', 'of', 'the', 'National', 'People', "'", 's', 'Congress', 'and', 'chairman', 'of', 'the', 'Central', 'Committee', 'of', 'the', 'Democratic', 'League', ',', 'delivered', 'a', 'congratulatory', 'speech', 'on', 'behalf', 'of', 'the', 'central', 'committees', 'of', 'the', 'democratic', 'parties', 'and', 'the', 'All', '-', 'China', 'Federation', 'of', 'Industry', 'and', 'Commerce', '.']
# ['Zhang', 'Baowen', ',', 'Vice', 'President', 'of', 'the', 'NPC', 'Standing', 'Committee', 'and', 'President', 'of', 'the', 'NLD', ',', 'delivered', 'a', 'congratulatory', 'message', 'on', 'behalf', 'of', 'the', 'Central', 'Committee', 'of', 'the', 'Democratic', 'Parties', 'and', 'the', 'All', '-', 'China', 'Federation', 'of', 'Industry', 'and', 'Commerce', '.']
# 0.3521727504653613
# 0.3783193191446539
# 0.3521727504653613
# ['Yan', 'Junqi', ',', 'executive', 'chairman', 'of', 'the', 'presidium', 'of', 'the', 'conference', ',', 'delivered', 'a', 'work', 'report', 'on', 'behalf', 'of', 'the', '13th', 'Central', 'Committee', 'of', 'the', 'Democratic', 'Progressive', 'Party', '.']
# ['Yan', 'Juanqi', ',', 'executive', 'chairman', 'of', 'the', 'Presidium', 'of', 'the', 'General', 'Assembly', ',', 'made', 'a', 'work', 'report', 'on', 'behalf', 'of', 'the', '13th', 'Central', 'Committee', 'of', 'the', 'Democratic', 'Progressive', 'Party', '.']
# ['Yan', 'Junqi', ',', 'standing', 'chairman', 'of', 'the', 'presidium', 'of', 'the', 'congress', ',', 'delivered', 'a', 'work', 'report', 'on', 'behalf', 'of', 'the', '13th', 'Central', 'Committee', 'of', 'the', 'DPP', '.']
# ['Yan', 'Junqi', ',', 'Executive', 'President', 'of', 'the', 'presidium', 'of', 'the', 'General', 'Assembly', ',', 'delivered', 'a', 'working', 'report', 'on', 'behalf', 'of', 'the', '13th', 'Central', 'Committee', 'of', 'the', 'People', "'", 's', 'Republic', 'of', 'China', '.']
# 0.23035153323575028
# 0.20142574712176725
# 0.21173073717442328
# ['Liu', 'Yandong', ',', 'You', 'Quan', ',', 'Xiangba', 'Pingcuo', ',', 'Zhang']
# ['Liu', 'Yandong', ',', 'You', 'Quan', ',', 'Xiangba', 'Pingcuo', ',', 'Zhang']
# ['Liu', 'Yandong', ',', 'You', 'Quan', ',', 'Xiang', 'Ba', 'Pingcuo', ',', 'Zhang']
# ['Liu', 'Yandong', ',', 'You', 'Quan', ',', 'Qiangba', 'Puncog', ',', 'Zhang', 'Qingli', ',']
# 0.24774880520147025
# 0.24774880520147025
# 0.2763052574207999
# ['Reviewed', 'and', 'passed', 'the', 'Constitution', 'of', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', 'Amendment', ')', 'and', 'elected', 'the', '14th', 'Central', 'Committee', 'of', 'the', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', '.']
# ['The', 'Constitution', 'of', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', 'Amendment', ')', 'was', 'reviewed', 'and', 'adopted', ',', 'and', 'the', '14th', 'Central', 'Committee', 'of', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', 'was', 'elected', '.']
# ['We', 'deliberated', 'and', 'adopted', 'the', 'Constitution', 'of', 'the', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', 'Amendment', ')', 'and', 'elected', 'the', '14th', 'Central', 'Committee', 'of', 'the', 'China', 'Association', 'for', 'the', 'Promotion', 'of', 'Democracy', '.']
# ['and', 'the', 'review', 'has', 'approved', 'the', 'Articles', 'Amendments', ')', 'of', 'the', 'China', 'Association', 'Promoting', 'Democracy', ',', 'and', 'will', 'select', 'the', '14th', 'Central', 'Committee', 'of', 'the', 'China', 'Association', 'Promoting', 'Democracy', '.']
# 0.1366683692397261
# 0.07521094428850011
# 0.1366683692397261
# ['The', 'People', "'", 's', 'Daily', ',', 'which', 'will', 'be', 'published', 'tomorrow', 'by', 'our', 'station', ',', 'will', 'publish', 'Unremitting', 'Efforts', 'Towards', 'the', 'Goal', 'of', 'Building', 'a', 'Powerful', 'Cyber', 'Nation', ',', 'General', 'Secretary', 'Xi', 'Jinping', 'Leads', 'and', 'Promotes', 'the', 'Strategy', 'of', 'a', 'Powerful', 'Cyber', 'Nation', '"']
# ['The', 'People', "'", 's', 'Daily', ',', 'which', 'will', 'be', 'published', 'tomorrow', ',', 'will', 'publish', 'a', 'summary', 'of', 'the', 'strategy', 'of', 'making', 'unremitting', 'efforts', 'towards', 'the', 'goal', 'of', 'building', 'a', 'network', 'power', ',', 'and', 'General', 'Secretary', 'Xi', 'Jinping', 'leading', 'and', 'promoting', 'the', 'network', 'power', '.']
# ['The', 'People', "'", 's', 'Daily', 'will', 'publish', 'a', 'review', 'of', 'the', 'strategy', 'of', 'General', 'Secretary', 'Xi', 'Jinping', 'in', 'building', 'the', 'goal', 'of', 'building', 'a', 'cyber', 'power', '.']
# ['In', 'news', 'delivered', 'to', 'this', 'station', ',', 'in', 'tomorrow', 'People', "'", 's', 'Daily', ',', 'the', 'article', 'Making', 'Unremitting', 'Efforts', 'Towards', 'the', 'Goal', 'of', 'Building', 'a', 'Cyberpower', ',', 'the', 'Strategic', 'Review', 'On', 'General', 'Secretary', 'Xi', 'Jinping', "'", 's', 'Leadership', 'on', 'Promoting', 'a', 'Cyberpower', '"', 'will', 'be', 'published', '.']
# 0.16922199023108436
# 0.0659596235981742
# 0.02024150123302193
# ['and', 'the', 'five', '-', 'year', 'large', '-', 'scale', 'achievement']
# ['A', 'five', '-', 'year', 'large', '-', 'scale', 'achievement', 'exhibition', 'with', 'perseverance', 'and', 'forge']
# ['And', 'the', 'five', '-', 'year', 'large', '-', 'scale', 'achievement']
# ['and', 'the', 'Forge', 'Ahead', 'Five', '-', 'Year', 'Major', 'Achievements', 'Exhibition', '.']
# 0.21842304453161157
# 0.5407177233198407
# 0.43297290548221834
# ['We', 'regard', 'China', 'as', 'the', 'future', 'development', 'direction', 'of', 'the', 'world', ',', 'especially', 'Marxism', '-', 'Leninism', 'is', 'not', 'a', 'dogma', 'it', 'is', 'a', 'philosophy', 'that', 'must', 'adapt', 'to', 'the', 'development', 'of', 'the', 'country', 'itself', '.']
# ['We', 'regard', 'China', 'as', 'the', 'future', 'development', 'direction', 'of', 'the', 'world', ',', 'especially', 'Marxism', '–', 'Leninism', ',', 'which', 'is', 'not', 'a', 'dogma', ',', 'but', 'a', 'philosophy', 'and', 'must', 'adapt', 'to', 'the', 'development', 'of', 'the', 'country', 'itself', '.']
# ['We', 'regard', 'China', 'as', 'the', 'future', 'development', 'direction', 'of', 'the', 'world', ',', 'especially', 'since', 'Marxism', '-', 'Leninism', 'is', 'not', 'a', 'dogma', '.', 'It', 'is', 'a', 'philosophy', 'that', 'must', 'adapt', 'to', 'the', 'development', 'of', 'the', 'country', 'itself', '.']
# ['We', 'regard', 'China', 'as', 'the', 'world', "'", 's', 'future', 'development', 'direction', '.', 'In', 'particular', ',', 'Marxism', '-', 'Leninism', 'is', 'not', 'a', 'dogma', '.', 'It', 'is', 'a', 'philosophy', ',', 'and', 'must', 'be', 'adapted', 'to', 'the', 'development', 'of', 'the', 'country', 'itself', '.']
# 0.2771826769557604
# 0.22474344977137165
# 0.38873835898218156
# ['This', 'is', 'what', 'the', 'Chinese', 'Communist', 'Party', 'is']
# ['This', 'is', 'what', 'the', 'Communist', 'Party', 'of', 'China', 'CPC', ')', 'is', 'doing', '.']
# ['This', 'is', 'what', 'the', 'Chinese', 'Communist', 'Party', 'is']
# ['This', 'is', 'what', 'the', 'Chinese', 'Communist', 'Party', 'is', 'doing', '.']
# 0.4993730363593433
# 0.2773927923720353
# 0.4993730363593433
# ['The', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Peasants', 'and', 'Workers', 'Democratic', 'Party', 'closed', 'in', 'Beijing', 'on', 'December', '1st', '.', 'The', 'meeting', 'successfully', 'completed', 'various', 'agenda', 'items', 'and', 'voted', 'to', 'pass']
# ['The', '16th', 'National', 'Congress', 'of', 'the', 'Democratic', 'Party', 'of', 'China', 'Agriculture', ',', 'Workers', 'and', 'Peasants', 'closed', 'in', 'Beijing', 'on', 'December', '1st', '.', 'The', 'agenda', 'of', 'the', 'congress', 'was', 'successfully', 'completed', 'and', 'passed', 'by', 'voting', '.']
# ['The', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Agricultural', 'and', 'Workers', "'", 'Democratic', 'Party', 'concluded', 'in', 'Beijing', 'on', 'December', '1st', ',', 'successfully', 'completing', 'the', 'agenda', 'and', 'voted']
# ['The', '16th', 'National', 'Congress', 'of', 'Chinese', 'Peasants', "'", 'and', 'Workers', "'", 'Democratic', 'Party', 'was', 'closed', 'in', 'Beijing', 'on', 'December', '1', '.', 'The', 'conference', 'successfully', 'completed', 'its', 'entire', 'agenda', ',', 'and', 'voted', 'upon', 'and']
# 0.15255782950479058
# 0.15455699193831238
# 0.14129625432589143
# ['Resolution', 'of', 'the', 'Sixteenth', 'National', 'Congress', 'of', 'the', 'Chinese', 'Migrant', 'Workers', 'Democratic', 'Party', ',', 'Resolution', 'on', 'the', 'Report', 'of', 'the', 'Fifteenth', 'Central', 'Committee', 'of', 'the', 'Sixteenth', 'National', 'Congress', 'of', 'the', 'Chinese', 'Migrant', 'Workers', 'Democratic', 'Party', '.']
# ['Resolutions', 'of', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Democratic', 'Party', 'of', 'Migrant', 'Workers', 'in', 'China', ',', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Democratic', 'Party', 'of', 'Migrant', 'Workers', 'in', 'China', 'and', 'the', 'report', 'of', 'the', '15th', 'Central', 'Committee', '.']
# ['Resolution', 'of', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Migrant', 'Democratic', 'Party', ',', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Migrant', 'Democratic', 'Party', ',', 'resolution', 'on', 'the', 'report', 'of', 'the', '15th', 'Central', 'Committee', '.']
# ['the', 'Resolution', 'of', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Peasants', "'", 'and', 'Workers', "'", 'Democratic', 'Party', ',', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Chinese', 'Peasants', "'", 'and', 'Workers', "'", 'Democratic', 'Party', ',', 'Resolution', 'on', 'the', 'Report', 'of', 'the', '15th', 'Central', 'Committee', '.']
# 0.12844306707676864
# 0.12136947691395741
# 0.1591836362704778
# ['Strengthen', 'self', '-', 'construction', 'in', 'an', 'all', '-', 'round', 'way', ',', 'and', 'resolutely', 'implement', 'the', 'work', 'arrangements', 'of', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Peasants', 'and', 'Workers', 'Party', '.']
# ['Strengthen', 'self', '-', 'construction', 'in', 'an', 'all', '-', 'round', 'way', 'and', 'resolutely', 'implement', 'the', 'work', 'arrangements', 'of', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Agricultural', 'Workers', "'", 'Party', '.']
# ['We', 'will', 'comprehensively', 'strengthen', 'self', '-', 'improvement', 'and', 'resolutely', 'implement', 'all', 'the', 'work', 'arrangements', 'for', 'the', '16th', 'National', 'Congress', 'of', 'the', 'Peasant', 'and', 'Labor', 'Party', '.']
# ['comprehensively', 'strengthen', 'self', '-', 'construction', ',', 'and', 'resolutely', 'implement', 'the', 'work', 'arrangements', 'of', 'the', '16th', 'Chinese', 'Peasants', "'", 'and', 'Workers', "'", 'Democratic', 'Party', ',']
# 0.32537233065925897
# 0.2788361030066266
# 0.1030565724287075
# ['With', 'a', 'new', 'mental', 'outlook', 'and', 'a', 'high', '-', 'spirited', 'attitude', 'of']
# ['With', 'a', 'brand', '-', 'new', 'mental', 'outlook', 'and', 'a', 'high', '-', 'spirited', 'attitude', 'of']
# ['With', 'a', 'brand', '-', 'new', 'spirit', 'and', 'a', 'high', 'attitude', 'of']
# ['with', 'a', 'new', 'spirit', 'and', 'high', '-', 'spirited']
# 0.34798423382515054
# 0.30064090577033237
# 0.30064090577033237
# ['Write', 'a', 'brilliant', 'chapter', 'worthy', 'of', 'the', 'new']
# ['Write', 'a', 'brilliant', 'chapter', 'worthy', 'of', 'the', 'new']
# ['Write', 'a', 'brilliant', 'chapter', 'worthy', 'of', 'the', 'new']
# ['write', 'a', 'brilliant', 'chapter', 'worthy', 'of', 'a', 'new', 'era', '.']
# 0.2160337239177047
# 0.2160337239177047
# 0.2160337239177047
# ['Reviewed', 'and', 'approved', 'the', 'amendment', 'to', 'the', 'Articles', 'of', 'Association', 'of', 'Jiu', 'San', 'Society', 'and', 'decided', 'to', 'submit', 'it', 'to', 'the', 'Eleventh', 'National', 'Congress', 'of', 'Jiu', 'San', 'Society', 'for', 'deliberation', '.']
# ['The', 'amendments', 'to', 'the', 'articles', 'of', 'association', 'of', 'Jiu', 'San', 'Society', 'were', 'reviewed', 'and', 'approved', ',', 'and', 'it', 'was', 'decided', 'to', 'submit', 'them', 'to', 'the', '11th', 'National', 'Congress', 'of', 'Jiu', 'San', 'Society', 'for', 'deliberation', '.']
# ['Deliberated', 'and', 'adopted', 'the', 'amendments', 'to', 'the', 'articles', 'of', 'association', 'of', 'the', 'Jiusan', 'Society', 'and', 'decided', 'to', 'submit', 'them', 'to', 'the', '11th', 'National', 'Congress', 'of', 'the', 'Jiusan', 'Society', 'for', 'deliberation', '.']
# ['The', 'review', 'has', 'approved', 'the', 'amendment', 'to', 'the', 'constitution', 'of', 'the', 'Jiu', 'San', 'Society', 'and', 'decided', 'to', 'submit', 'it', 'to', 'the', '11th', 'National', 'Congress', 'of', 'Jiu', 'San', 'Society', 'for', 'review', '.']
# 0.3753962563316515
# 0.22300477171000072
# 0.15910571527998144
# ['Has', 'assisted', 'more', 'than', '10', ',', '000', 'tourists', 'to', 'return', 'home']
# ['More', 'than', '10', 'thousand', 'tourists', 'have', 'been', 'assisted', 'to', 'return', 'home']
# ['It', 'has', 'assisted', 'more', 'than', '10', ',', '000', 'tourists', 'to', 'return', 'home']
# ['to', 'help', 'more', 'than', '10', ',', '000', 'tourists', 'return', 'home', 'safely', '.']
# 0.3198163372315327
# 0.38451710850356896
# 0.35025307890862434
# ['As', 'of', 'now', ',', 'Bali', 'Airport', 'is', 'still', 'temporarily', 'open', '.']
# ['Up', 'to', 'now', ',', 'Bali', 'Airport', 'is', 'still', 'temporarily', 'open', '.']
# ['So', 'far', ',', 'the', 'Bali', 'airport', 'is', 'still', 'temporarily', 'open', '.']
# ['At', 'present', ',', 'the', 'airport', 'in', 'Bali', 'is', 'still', 'temporarily', 'open', '.']
# 0.19653956110926118
# 0.19653956110926118
# 0.23322141549146388

# %%
# 输出结果
print(sum(google_score)/len(google_score))
print(sum(sg_score)/len(sg_score))
print(sum(jscb_score)/len(jscb_score))
# Out:
# 0.2787240329824863
# 0.2629586689606913
# 0.24164962511335086
